# %% [markdown]
# # This notebook has been superseded
#
# Use one of these instead:
#
# - **`train_retinaguard_colab_ALLINONE.ipynb`** — recommended. Runs training, evaluation, saves to Google Drive live, and auto-publishes proofs to GitHub + the trained weights as a Release. Built for an unattended overnight run on Colab.
# - **`train_retinaguard_kaggle.ipynb`** — if you prefer Kaggle (uses the mounted competition dataset; no kaggle.json upload needed).
